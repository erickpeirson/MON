# %%
from nltk.corpus import stopwords
import string
import rdflib
import urllib2
from urllib2 import HTTPError
import xml.etree.ElementTree as ET
import os
import subprocess
import pickle
import matplotlib.pyplot as plt
import simplejson

# %% [markdown]
# ## Relevant paths & services

# %%
orgpath = '/Users/erickpeirson/Model Organisms in Neuroscience/data'

# %%
datapath = orgpath + '/RDF'

# %%
taxonomy_api = "http://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=taxonomy"
taxonomy_api_get = "http://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=taxonomy"

# %% [markdown]
# ## Methods

# %%
def find_names(paper, linnaeus_path="/Applications/linnaeus/bin/linnaeus-2.0.jar", tmp_path="/tmp/"):
    """
    Yields a NCBI Taxonomy id for organisms, via LINNAEUS NER.

    Calls the LINNAEUS NER engine to find organism names (common & scientific) in the
    paper title and abstract.
    """

    with open(tmp_path+"text.txt", 'w') as f:
        f.write(str(strip_non_ascii(paper.title)) + "\n")
        f.write(str(strip_non_ascii(paper.abstract)) + "\n")
    
    subprocess.call(['java', '-jar', linnaeus_path, '--text', tmp_path+"text.txt", '--out', tmp_path+"results.tsv" ])
    
    with open(tmp_path+"results.tsv", 'r') as f:
        results = [ line.strip('\n').split('\t') for line in f.readlines() ]
    
    return set([ r[0].split(':')[-1] for r in results[1:] ])

# %%
taxon_cache = {}

# %%
def get_taxon(taxon):
    """
    Retries information about a specific taxon, by ID.
    """
    try:
        return taxon_cache[taxon]
    except KeyError:
        response = urllib2.urlopen(taxonomy_api_get + "&id=" + taxon).read()
        taxon_cache[taxon] = ET.fromstring(response)
        return taxon_cache[taxon]

# %%
# Cache for classify()
classified = {}

# %%
def classify(taxon):
    """
    Yields the higher-level taxonomic group to which taxon belongs.

    Retrieves data for taxon from NCBI Taxonomy, then passes the result
    to merge() to classify. Uses classified (dict) to cache results.
    """
    try:
        return classified[taxon]
    except KeyError:
        xml = get_taxon(taxon)
#        response = urllib2.urlopen(taxonomy_api_get + "&id=" + taxon).read()
#        xml = ET.fromstring(response)
        merged = merge(xml)
        classified[taxon] = merged 
        return merged

# %%
def merge(result):
    """
    Uses NCBI Taxonomy XML response to decide to which higher-level
    taxonomic group a taxon belongs.
    """
    
    taxa = [ tax.text for tax in result.findall('.//TaxId') ]
    if '89593' in taxa: # Craniata
        if '7898' in taxa or '7894' in taxa or '7878' in taxa: # Fishes
            return 'Fish'
        elif '8292' in taxa: # Amphibeans
            return 'Amphibean'
        elif '40674' in taxa: # Mammals
            if '9681' in taxa: # Cats
                return 'Cat'
            elif '10066' in taxa: # Mice & rats
                return 'Mouse or Rat'
            elif '9443' in taxa: # Primates
                if '9605' in taxa: # Human
                    return 'Human'
                elif '9539' in taxa: # Macaque
                    return 'Macaque'
                else:
                    return 'Other Primate'
            else: # Other mammals
                return 'Other Mammal'
        # Remainder
        return 'Other Craniata'
    else: # Not in Craniata
        return 'Non-Craniata'

# %%
class paper:
    """
    Describes a minimal PubMed entry.
    """
    def __init__(self, uri, abstract, journal, title):
        self.uri = uri
        self.abstract = abstract
        self.journal = journal
        self.title = title

# %%
pmid2doi_cache = {}

# %%
def pmid2doi(pmid):
    """
    >>> pmid2doi('17671991')
    {'doi': '10.1002/jnr.21440', 'pmid': 17671991}
    """
    try:
        return pmid2doi_cache[pmid]
    except KeyError:
        endpoint = "http://www.pmid2doi.org/rest/json/doi/"
        query = endpoint + str(pmid)
        response = simplejson.loads(urllib2.urlopen(query).read())
        pmid2doi_cache[pmid] = response
        return response

# %% [markdown]
# ## General utility methods

# %%
def tokenize(s):
    s = s.translate(string.maketrans("",""), string.punctuation)
    return s.lower().split()

# %%
def remove_stopwords(t):
    return [ word for word in t if word not in stopwords.words() and word != 'ab' ]

# %%
def strip_non_ascii(string):
    ''' Returns the string without non ASCII characters'''
    stripped = (c for c in string if 0 < ord(c) < 127)
    return ''.join(stripped)

# %%
def remove_integers(t):
    new_t = []
    for word in t:
        try:
            int(word)
        except ValueError:
            new_t.append(word)
    return new_t

# %%
class dictionary:
    """
    A two-way index for integer/string pairs.
    """
    def __init__(self):
        self.by_str = {}
        self.by_int = {}
        
    def __setitem__(self, key, value):
        if type(key) == str:
            self.by_str[key] = value
            self.by_int[value] = key
        if type(key) == int:
            self.by_int[key] = value
            self.by_str[value] = key
    
    def __getitem__(self, key):
        if type(key) == str:
            return self.by_str[key]
        if type(key) == int:
            return self.by_int[key]

# %% [markdown]
# ## Parse RDF

# %%
g = rdflib.Graph()
for filename in os.listdir(datapath):
    if filename.split('.')[-1] == 'rdf':
        g.load(datapath+"/"+filename)

# %% [markdown]
# ### For convenience, index RDF triples.

# %%
asdict = {}    # Index by subject.
for s,p,o in g:  # Subject, predicate, and object in RDF triple.
    try:
        asdict[s][p] = o
    except KeyError:
        asdict[s] = {}
        asdict[s][p] = o

# %% [markdown]
# ### Generate a list of papers (see class `paper`, above)

# %%
aslist = []
for key, value in asdict.iteritems():
    type_key = rdflib.term.URIRef(u'http://www.w3.org/1999/02/22-rdf-syntax-ns#type')
    article_key = rdflib.term.URIRef(u'http://purl.org/net/biblio#Article')
    if value[type_key] == article_key:
        try:
            p = paper(key, value[rdflib.term.URIRef(u'http://purl.org/dc/terms/abstract')], value[rdflib.term.URIRef(u'http://purl.org/dc/terms/isPartOf')], value[rdflib.term.URIRef(u'http://purl.org/dc/elements/1.1/title')])
            aslist.append(p)
        except KeyError:
            pass

# %%
len(aslist) # number of abstracts
# Out:
# 9278

# %% [markdown]
# ## Generate a complete vocabulary for the set of `paper` abstracts
# * Remove all integers
# * Remove stopwords (NLTK stopwords)
# * Calculate overall term frequencies ( `termcounts` )
# * Index the vocabulary ( `mo_dict` )

# %%
vocabulary = set([])
for p in aslist:
    s = str(strip_non_ascii(p.abstract))
    words = set(tokenize(s))
    vocabulary = vocabulary | words

# %%
vocabulary = remove_integers(list(vocabulary))

# %%
vocabulary = set(vocabulary) - set([word for word in stopwords.words()])

# %%
len(vocabulary)
# Out:
# 51853

# %%
termcounts = {}
for p in aslist:
    for term in tokenize(str(strip_non_ascii(p.abstract))):
        try:
            termcounts[term] += 1
        except KeyError:
            termcounts[term] = 1

# %%
mo_dict = dictionary()
i = 0
for word in list(vocabulary):
    mo_dict[word] = i
    i += 1

# %% [markdown]
# ## First attempt: dictionary look-up for each term, using NCBI Taxonomy (slow)

# %%
species = []
for word in list(vocabulary):
    found = False
    response = urllib2.urlopen(taxonomy_api + "&term=" + word).read()
    xml = ET.fromstring(response)
    for e in xml:
        if e.tag == 'Count':
            if int(e.text) > 0:
                found = True
                name = word
        if e.tag == 'IdList' and len(e) > 0:
            ident = e[0].text
    if found:
        response = urllib2.urlopen(taxonomy_api_get + "&id=" + ident).read()
        xml = ET.fromstring(response)
        for e in xml[0]:
            if e.tag == 'Rank':
                rank = e.text
        species.append( (name, rank, ident) )
# Out:
# heliothis found
# genus
# polygala found
# genus
# canaries found
# species
# fiv found
# species
# catharus found
# genus
# rice found
# species
# platyrhinoidis found
# genus
# crows found
# genus
# medaka found
# species
# callithrix found
# genus
# lutra found
# genus
# echidna found
# genus
# gerbils found
# subfamily
# helisoma found
# genus
# loxia found
# genus
# munida found
# genus
# eublepharinae found
# subfamily
# scv found
# species
# borrelia found
# genus
# enterovirus found
# genus
# aves found
# class
# apterostigma found
# genus
# dinornis found
# genus
# campylobacter found
# genus
# amoeba found
# genus
# amphibians found
# class
# taeniopygia found
# genus
# horseradish found
# species
# hippidae found
# family
# retrovirus found
# species
# chorus found
# genus
# juncos found
# genus
# calyx found
# genus
# chat found
# species
# trypanosoma found
# genus
# zingiberaceae found
# family
# bullfrogs found
# species
# oryzias found
# genus
# chlamydia found
# genus
# alpaca found
# species
# aplysia found
# genus
# barley found
# subspecies
# coffee found
# species
# dogs found
# subspecies
# siluriformes found
# order
# emu found
# species
# codon found
# genus
# cylinder found
# genus
# beetles found
# order
# himantura found
# genus
# isis found
# genus
# dialysis found
# genus
# prosimians found
# suborder
# corona found
# genus
# soa found
# genus
# epomophorus found
# genus
# mrv found
# species
# datura found
# genus
# bungarus found
# genus
# oncorhynchus found
# genus
# emus found
# genus
# psammomys found
# genus
# delphinus found
# genus
# sarcophagidae found
# family
# cea found
# genus
# pseudomonas found
# genus
# horse found
# species
# lentivirus found
# genus
# tetraodontiformes found
# order
# woodchuck found
# species
# polistes found
# genus
# allium found
# genus
# caenorhabditis found
# genus
# sturnus found
# genus
# dromaius found
# genus
# podargidae found
# family
# dicentrarchus found
# genus
# caprimulgidae found
# family
# camera found
# genus
# cannula found
# genus
# carnivores found
# order
# anura found
# order
# timea found
# genus
# tobacco found
# species
# rajiformes found
# order
# tetrapods found
# no rank
# pieris found
# genus
# homo found
# genus
# pogona found
# genus
# palaeognathae found
# superorder
# coelacanths found
# family
# abra found
# genus
# tibicen found
# genus
# mea found
# genus
# root found
# no rank
# ovo found
# species
# athletes found
# genus
# tigerfish found
# species
# ginger found
# species
# artificial found
# species
# cockatoos found
# family
# syncope found
# genus
# soursop found
# species
# centella found
# genus
# spirulina found
# suborder
# reptiles found
# order
# mscv found
# species
# elephants found
# family
# lampetra found
# genus
# icterus found
# genus
# haplochromis found
# genus
# beta found
# genus
# seal found
# family
# necturus found
# genus
# adenovirus found
# species
# metazoans found
# kingdom
# galeomorphii found
# no rank
# tosv found
# no rank
# holocephali found
# subclass
# amniotes found
# no rank
# lampreys found
# family
# hamsters found
# subfamily
# erinaceus found
# genus
# protopterus found
# genus
# janus found
# genus
# anostostomatidae found
# family
# cicada found
# genus
# planes found
# genus
# panax found
# genus
# chp found
# species
# carduelis found
# genus
# platypus found
# genus
# euryapteryx found
# genus
# praxis found
# genus
# phascogale found
# genus
# pavo found
# genus
# dcv found
# species
# tinamous found
# order
# anemia found
# genus
# plasmid found
# species
# rodents found
# order
# mus found
# subgenus
# mum found
# species
# lonchura found
# genus
# astasia found
# genus
# apteryx found
# genus
# renilla found
# genus
# bats found
# order
# notoryctemorphia found
# order
# cladistia found
# no rank
# goes found
# genus
# macaca found
# genus
# homoptera found
# order
# starling found
# species
# alopias found
# genus
# escherichia found
# genus
# redpoll found
# species
# turkey found
# species
# catfish found
# species
# whales found
# order
# pontoporia found
# genus
# mycobacterium found
# genus
# marsupials found
# no rank
# estrildidae found
# family
# bowerbirds found
# family
# harlequin found
# species
# horses found
# family
# agnosia found
# genus
# lambs found
# species
# melanogaster found
# genus
# mustela found
# genus
# lucifer found
# genus
# shrews found
# family
# stenosis found
# genus
# pelodiscus found
# genus
# urosaurus found
# genus
# psittaciformes found
# order
# strigiformes found
# order
# glaucoma found
# genus
# nematodes found
# genus
# aquifex found
# genus
# ape found
# superfamily
# parrots found
# family
# sminthopsis found
# genus
# myliobatiformes found
# order
# chaos found
# genus
# arcturus found
# genus
# unknown found
# species
# vertebrates found
# no rank
# cephalopods found
# class
# polyomavirus found
# genus
# alexa found
# genus
# spio found
# genus
# trichogaster found
# genus
# niger found
# species
# anguilla found
# genus
# permit found
# species
# taeniura found
# genus
# opossums found
# family
# stomatorhinus found
# genus
# plethodon found
# genus
# ips found
# genus
# frogs found
# order
# spot found
# species
# data found
# genus
# acipenser found
# genus
# bovine found
# species
# ostrich found
# species
# pleurodeles found
# genus
# cis found
# genus
# galatheidae found
# family
# ants found
# family
# actinopterygi found
# class
# froglets found
# genus
# emesis found
# genus
# mammals found
# class
# pica found
# genus
# axis found
# genus
# indicator found
# genus
# cucumber found
# varietas
# crayfish found
# superfamily
# ling found
# species
# agkistrodon found
# genus
# clostridium found
# genus
# pipidae found
# family
# sciaenidae found
# family
# anomia found
# genus
# scincus found
# genus
# laser found
# genus
# onion found
# species
# mhv found
# no rank
# oilbird found
# species
# swifts found
# genus
# cataglyphis found
# genus
# aka found
# genus
# callipepla found
# genus
# cow found
# species
# wasps found
# family
# aegothelidae found
# family
# chordates found
# phylum
# thalassoma found
# genus
# hala found
# species
# e9 found
# no rank
# sheep found
# species
# zebrafish found
# species
# comet found
# species
# bias found
# genus
# dinornithiformes found
# order
# caprimulgiformes found
# order
# monotremes found
# order
# chorda found
# genus
# gonodactylus found
# genus
# vertigo found
# genus
# tachyglossus found
# genus
# tadarida found
# genus
# peromyscus found
# genus
# baboons found
# genus
# cotton found
# species
# gv found
# genus
# astatotilapia found
# genus
# gekkota found
# infraorder
# attini found
# tribe
# bee found
# superfamily
# ber found
# species
# thrushes found
# family
# apodiformes found
# order
# suzuki found
# species
# dmv found
# species
# pinus found
# subgenus
# lavender found
# species
# tela found
# genus
# panacea found
# genus
# hagfishes found
# family
# iso found
# genus
# tilapia found
# genus
# sturgeon found
# species
# marijuana found
# species
# rana found
# subgenus
# ia found
# genus
# rhis found
# genus
# xenopus found
# subgenus
# nightjar found
# species
# alligator found
# genus
# crocuta found
# genus
# manatees found
# family
# scyliorhinus found
# genus
# polyomaviruses found
# genus
# primer found
# species
# yeast found
# species
# ornithorhynchus found
# genus
# rays found
# superorder
# skates found
# order
# amphioxus found
# species
# carcharodon found
# genus
# eutheria found
# no rank
# honesty found
# species
# placentals found
# no rank
# serinus found
# genus
# j1 found
# species
# puma found
# genus
# cancer found
# genus
# dingo found
# subspecies
# acomys found
# genus
# hybrid found
# species
# laurasiatheria found
# superorder
# limax found
# genus
# none found
# species
# idea found
# genus
# xanthoxylum found
# genus
# listeria found
# genus
# ferret found
# subspecies
# hippocampus found
# genus
# diplodactylinae found
# family
# fishes found
# no rank
# fisher found
# species
# trachea found
# genus
# chelator found
# genus
# pantodon found
# genus
# sv40 found
# species
# carassius found
# genus
# glycine found
# genus
# rabbits found
# species
# svc found
# species
# ciona found
# genus
# gatekeeper found
# species
# aspergillus found
# genus
# uncaria found
# genus
# viruses found
# superkingdom
# cockroaches found
# order
# antechinus found
# genus
# corn found
# subspecies
# stegastes found
# genus
# steatornis found
# genus
# pmv found
# species
# unidentified found
# species
# cinnamon found
# species
# orectolobus found
# genus
# macropodus found
# genus
# prv found
# species
# decodes found
# genus
# ginseng found
# species
# trichechus found
# genus
# primates found
# order
# podargus found
# genus
# haglidae found
# family
# virginia found
# genus
# dasyuromorphia found
# order
# seals found
# family
# rats found
# species
# dermophis found
# genus
# cuckoos found
# family
# rails found
# family
# cetorhinus found
# genus
# soricomorpha found
# order
# iguania found
# suborder
# peramelemorphia found
# order
# flies found
# order
# sepsis found
# genus
# pigeons found
# family
# pseudosphromenus found
# genus
# squalus found
# genus
# petromyzon found
# genus
# lemon found
# species
# electron found
# genus
# cat found
# species
# fev found
# species
# columba found
# genus
# dunnart found
# species
# latimeria found
# genus
# ray found
# species
# torpedo found
# genus
# ichthyomyzon found
# genus
# saimiri found
# genus
# bichirs found
# family
# limulus found
# genus
# monitors found
# family
# tinamidae found
# family
# bilateria found
# no rank
# hhv6 found
# species
# hhv8 found
# species
# mormyridae found
# family
# glomus found
# genus
# carpodacus found
# genus
# insects found
# superclass
# phyla found
# subgenus
# megachiroptera found
# suborder
# pea found
# species
# parvovirus found
# genus
# palinura found
# infraorder
# taricha found
# genus
# agamidae found
# family
# volvox found
# genus
# iva found
# genus
# chiloscyllium found
# genus
# junco found
# species
# cannabis found
# genus
# diprotodontia found
# order
# mycoplasma found
# genus
# angelica found
# genus
# characiformes found
# order
# t7 found
# species
# t4 found
# no rank
# t1 found
# species
# chinchillas found
# family
# helicobacter found
# genus
# elasmobranchii found
# subclass
# waterfowl found
# family
# grasshoppers found
# suborder
# alligators found
# subfamily
# damselfish found
# species
# thor found
# genus
# echinoderms found
# phylum
# gloeobacter found
# genus
# mice found
# species
# macrobrachium found
# genus
# squamata found
# order
# cabbage found
# varietas
# tomato found
# zonotrichia found
# genus
# chickens found
# species
# delta found
# genus
# ametrus found
# genus
# moca found
# genus
# marmosets found
# species
# treefrogs found
# genus
# echo found
# genus
# eukaryotes found
# superkingdom
# p22 found
# species
# apes found
# superfamily
# swans found
# genus
# gekkoninae found
# subfamily
# whale found
# order
# turdus found
# genus
# pseudemys found
# genus
# cytomegalovirus found
# genus
# leucoptera found
# genus
# coronavirus found
# genus
# snakes found
# infraorder
# bombus found
# subgenus
# ata found
# species
# atv found
# species
# bandicoots found
# family
# pusa found
# genus
# vectors found
# no rank
# ostariophysi found
# no rank
# ctenomys found
# genus
# spermophilus found
# genus
# roger found
# genus
# scavengers found
# family
# coma found
# genus
# quinine found
# species
# rhea found
# genus
# beaugregory found
# species
# mink found
# species
# lizards found
# superorder
# amniota found
# no rank
# phoca found
# genus
# ducks found
# genus
# scarabaeidae found
# family
# aroma found
# genus
# forsterygion found
# genus
# doa found
# genus
# dictyoptera found
# genus
# molluscs found
# phylum
# physalaemus found
# genus
# lucida found
# genus
# animals found
# kingdom
# picornavirus found
# family
# celastraceae found
# family
# pigs found
# species
# cctcc found
# species
# laminae found
# subfamily
# fimbria found
# genus
# danio found
# genus
# proteus found
# genus
# anomalopteryx found
# genus
# neisseria found
# genus
# deer found
# family
# ramp found
# species
# ochrogaster found
# genus
# paramecium found
# genus
# 37a found
# species
# name found
# species
# sharks found
# infraclass
# pitangus found
# genus
# melopsittacus found
# genus
# tettigoniidae found
# family
# nia found
# genus
# mayo found
# species
# serrasalmus found
# genus
# goldfish found
# species
# aoa found
# genus
# crocodilians found
# family
# nematode found
# species
# nematoda found
# phylum
# emblemasoma found
# genus
# pinna found
# genus
# annona found
# genus
# starlings found
# family
# galago found
# genus
# cats found
# species
# henipavirus found
# genus
# thrombus found
# genus
# turcica found
# genus
# ambystoma found
# genus
# broccoli found
# varietas
# lia found
# genus
# fossa found
# genus
# lobsters found
# species
# torpediniformes found
# order
# carolinensis found
# genus
# pteropus found
# genus
# myiozetetes found
# genus
# ammonia found
# genus
# geranium found
# species
# hiv1 found
# species
# psalmopoeus found
# genus
# hydrops found
# genus
# frogmouths found
# family
# bears found
# family
# anurans found
# order
# thymus found
# genus
# sphinx found
# genus
# compacta found
# genus
# steatornithidae found
# family
# tripterygium found
# genus
# phaseolus found
# genus
# prokaryotes found
# superkingdom
# bkv found
# species
# cichlids found
# family
# butterflyfish found
# family
# dioscorea found
# genus
# chess found
# species
# sly found
# species
# mate found
# species
# eidolon found
# genus
# dictyostelium found
# genus
# pera found
# genus
# pygocentrus found
# genus
# helix found
# genus
# anseriformes found
# order
# maia found
# genus
# deuterostomia found
# no rank
# california found
# genus
# polypterus found
# genus
# ensifera found
# genus
# peppermint found
# species
# turtles found
# order
# pan found
# genus
# macropus found
# genus
# honeybee found
# species
# unclassified found
# no rank
# coleoptera found
# order
# apis found
# genus
# chimpanzee found
# species
# hedgehogs found
# family
# cfa found
# species
# chondrostei found
# no rank
# starfishes found
# class
# passeriformes found
# order
# lilacs found
# genus
# polypteridae found
# family
# gallus found
# genus
# lens found
# genus
# diomedea found
# genus
# insectivores found
# order
# ectodini found
# tribe
# nebula found
# genus
# ioa found
# subgenus
# satellites found
# no rank
# dura found
# genus
# pig found
# species
# paris found
# genus
# labridae found
# family
# quiscalus found
# genus
# equine found
# species
# otolemur found
# genus
# rat found
# species
# lottia found
# genus
# achyranthes found
# genus
# tia found
# species
# bahia found
# genus
# bullfrog found
# species
# q1 found
# species
# sparrows found
# family
# toadfish found
# species
# nyctibiidae found
# family
# holothuria found
# genus
# molothrus found
# genus
# swift found
# species
# chordata found
# phylum
# poliovirus found
# species
# synthetic found
# species
# catfishes found
# order
# primate found
# order
# passer found
# genus
# alexia found
# genus
# bufo found
# genus
# hiv found
# species
# ara found
# genus
# pvm found
# species
# bronchus found
# genus
# wisteria found
# genus
# ass found
# species
# gsdiv found
# no rank
# saccharomyces found
# genus
# hemiptera found
# order
# spv found
# no rank
# rabbit found
# species
# dolphins found
# family
# musculus found
# genus
# purpura found
# genus
# catha found
# genus
# rousettus found
# genus
# metatheria found
# no rank
# chicken found
# species
# cola found
# genus
# geckos found
# family
# herpesvirus found
# species
# nonion found
# genus
# porphyria found
# genus

# %%
species_set = set([ s for s,r,i in species ])

# %%
counts = {}
for org,rank,ident in species:
    counts[org] = 0
    for p in aslist:
        if org in p.abstract:
            counts[org] += 1

# %%
fig = plt.figure(figsize(40, 10))
ax = fig.add_subplot(1, 1, 1)

names = [ k for k,v in counts.iteritems() if v > 10 ]
values = [ v/float(len(aslist)) for v in counts.values() if v > 10 ]
N = len(names)
ind = range(N)
ax.bar(ind, values, align='center')
ax.set_xticks(ind)
ax.set_xticklabels(names)
fig.autofmt_xdate()
plt.show()

# %% [markdown]
# ## Second attempt: LINNAEUS NER & merging via NCBI Taxonomy

# %%
paper_orgs = {}
journal_orgs = {}
for p in aslist:
    r = find_names(p)
    paper_orgs[p.uri] = r
    try:
        journal_orgs[p.journal]
    except KeyError:
        journal_orgs[p.journal] = {}
    for i in r:
        try:
            journal_orgs[p.journal][i] += 1
        except KeyError:
            journal_orgs[p.journal][i] = 1

# %%
by_journal = {}
for uri, values in journal_orgs.iteritems():
    rels = { p:v for p,v in g[uri] }
    title = str(rels[rdflib.term.URIRef(u'http://purl.org/dc/elements/1.1/title')])
    try:
        by_journal[title]
    except KeyError:
        by_journal[title] = {}
    for k,v in values.iteritems():
        try:
            by_journal[title][k] += v
        except KeyError:
            by_journal[title][k] = v

# %%
overall_taxa = {}
for paper,orgs in paper_orgs.iteritems():
    for org in orgs:
        taxon = classify(org)
        try:
            overall_taxa[taxon] += 1
        except KeyError:
            overall_taxa[taxon] = 1

# %%
journal_taxa = {}
for journal, orgs in by_journal.iteritems():
    journal_taxa[journal] = {}
    N = np.sum([c for c in orgs.values()])
    for org,count in orgs.iteritems():
        taxon = classify(org)
        try:
            journal_taxa[journal][taxon] += float(count)/N
        except KeyError:
            journal_taxa[journal][taxon] = float(count)/N

# %%
for journal, values in journal_taxa.iteritems():
    font = { 'size'   : 16}
    matplotlib.rc('font', **font)    
    
    fig = plt.figure(figsize=(20,10), dpi=300)
    ind = np.array(range(len(values)))
    plt.bar(ind, np.array(values.values())*100)
    plt.title(journal)
    ax = fig.add_subplot(1, 1, 1)
    ax.set_xticks(ind+0.5)
    ax.set_xticklabels(values.keys())
    plt.ylabel("Percent of Papers")
    fig.autofmt_xdate(rotation=90)
    plt.savefig("/Users/erickpeirson/Model Organisms in Neuroscience/figures/"+journal.lower().replace(' ','')+".png")

# %%
fig = plt.figure(figsize=(20,10), dpi=300)
ind = np.array(range(len(overall_taxa)))
plt.bar(ind, overall_taxa.values())
ax = fig.add_subplot(1, 1, 1)
ax.set_xticks(ind+0.5)
ax.set_xticklabels(overall_taxa.keys())
fig.autofmt_xdate(rotation=90)
plt.title("All Journals")
plt.ylabel("Number of Papers")
plt.savefig("/Users/erickpeirson/Model Organisms in Neuroscience/figures/alljournals.png")

# %% [markdown]
# ### Persistency

# %%
with open(orgpath+"/organisms.txt", "w") as f:
    for n,r,i in species:
        f.write(n + "\t" + r + "\t" + i + "\n")

# %%
with open(orgpath+"/organisms.txt", "r") as f:
    species = [ tuple(line.strip('\n').split('\t')) for line in f.readlines() ]

# %%
with open("/Users/erickpeirson/Model Organisms in Neuroscience/data/paper_orgs.pickle", "w") as f:
    pickle.dump(paper_orgs, f)
with open("/Users/erickpeirson/Model Organisms in Neuroscience/data/journal_orgs.pickle", "w") as f:
    pickle.dump(journal_orgs, f)
with open("/Users/erickpeirson/Model Organisms in Neuroscience/data/by_journal.pickle", "w") as f:
    pickle.dump(by_journal, f)
with open("/Users/erickpeirson/Model Organisms in Neuroscience/data/overall_taxa.pickle", "w") as f:
    pickle.dump(overall_taxa, f)
with open("/Users/erickpeirson/Model Organisms in Neuroscience/data/journal_taxa.pickle", "w") as f:
    pickle.dump(journal_taxa, f)

# %% [markdown]
# ## Validation

# %%
with open("/Users/erickpeirson/Model Organisms in Neuroscience/data/paper_orgs.pickle", "r") as f:
    papers_orgs = pickle.load(f)

# %%
with open("/Users/erickpeirson/Model Organisms in Neuroscience/data/journal_taxa.pickle", "rb") as f:
    journal_taxa = pickle.load(f)

# %%
journals = {}

# %%
for paper in aslist:
    jname = asdict[paper.journal][rdflib.term.URIRef(u'http://purl.org/dc/elements/1.1/title')]
    journals[paper.journal] = jname

# %%
journals_reverse = {}
for key,value in journals.iteritems():
    try:
        journals_reverse[value].append(key)
    except KeyError:
        journals_reverse[value] = [key]

# %%
jnr_papers = [ paper for paper in aslist if paper.journal in journals_reverse[rdflib.term.Literal(u'Journal of neuroscience research')] ]

# %%
orgs_by_doi = {}

# %%
def new_ns(uri):
    sep = uri.split('#')
    try:
        ident = sep[1]
        filename = sep[0].split('/')[-1]
    
        new_str = 'file://' + datapath + '/' + filename + '#' + ident
        return rdflib.term.URIRef(unicode(new_str))
    except IndexError:
        return uri

# %%
new_ns(papers_orgs.keys()[0])
# Out:
# rdflib.term.URIRef(u'file:///Users/erickpeirson/Model Organisms in Neuroscience/data/RDF/Glia.rdf#item_10886')

# %%
papers_orgs_ = { new_ns(k):v for k,v in papers_orgs.iteritems() }

# %%
papers_orgs_.keys()[0:10]
# Out:
# [rdflib.term.URIRef(u'file:///Users/erickpeirson/Model Organisms in Neuroscience/data/RDF/BrainAJournalofNeurology.rdf#item_17662'),
#  rdflib.term.URIRef(u'file:///Users/erickpeirson/Model Organisms in Neuroscience/data/RDF/BrainAJournalofNeurology.rdf#item_17660'),
#  rdflib.term.URIRef(u'file:///Users/erickpeirson/Model Organisms in Neuroscience/data/RDF/Glia.rdf#item_11378'),
#  rdflib.term.URIRef(u'file:///Users/erickpeirson/Model Organisms in Neuroscience/data/RDF/Glia.rdf#item_10436'),
#  rdflib.term.URIRef(u'file:///Users/erickpeirson/Model Organisms in Neuroscience/data/RDF/BrainAJournalofNeurology.rdf#item_17664'),
#  rdflib.term.URIRef(u'file:///Users/erickpeirson/Model Organisms in Neuroscience/data/RDF/Glia.rdf#item_11374'),
#  rdflib.term.URIRef(u'file:///Users/erickpeirson/Model Organisms in Neuroscience/data/RDF/BrainAJournalofNeurology.rdf#item_17668'),
#  rdflib.term.URIRef(u'file:///Users/erickpeirson/Model Organisms in Neuroscience/data/RDF/ActaNeuropathologica.rdf#item_22604'),
#  rdflib.term.URIRef(u'file:///Users/erickpeirson/Model Organisms in Neuroscience/data/RDF/Glia.rdf#item_11370'),
#  rdflib.term.URIRef(u'file:///Users/erickpeirson/Model Organisms in Neuroscience/data/RDF/Glia.rdf#item_11372')]

# %%
automatic_classification = {}

# %%
for paper in jnr_papers:
    doi = None
    
    rdf_record = asdict[paper.uri]
    idents = str(rdf_record[rdflib.term.URIRef(u'http://purl.org/dc/elements/1.1/description')]).split(' \n')
    idents_ = {}
    for ident in idents:
        ack = ident.split(': ')
        idents_[ack[0]] = ack[1]
    try:
        doi = pmid2doi(idents_['PMID'])['doi']
    except HTTPError:
        pass
    
    if doi is not None:
        org_names = []
        for taxon in papers_orgs_[rdflib.term.URIRef(paper.uri.replace('%20', ' '))]:
            taxid = taxon.split('?')[0]
            org_names += [ n.text for n in get_taxon(taxid).findall('.//OtherNames/CommonName') ]
    
        automatic_classification[doi] = '; '.join(org_names)

# %%
import xlrd

# %%
book = xlrd.open_workbook("/Users/erickpeirson/Model Organisms in Neuroscience/data/Manual/Journal of Neuroscience Research.xlsx")

# %%
manual_papers = []

# %%
for sheet in book.sheets():
    headers = [ sheet.cell(0,c).value for c in xrange(sheet.ncols) ]
    for r in xrange(1,sheet.nrows):
        mpaper = { headers[c]:sheet.cell(r,c).value for c in xrange(0, sheet.ncols) }
        try:
            if mpaper[u'DOI'] != '':
                manual_papers.append(mpaper)
        except KeyError:
            pass    # DOI not available for all papers.

# %%
manual_classification = { mp['DOI']:mp['Animal Models'] for mp in manual_papers }

# %%
import csv

# %%
with open(orgpath+'/validation.csv', 'wb') as f:
    writer = csv.writer(f)
    writer.writerow(['DOI', 'Manual', 'Automated'])
             
    for key in set(manual_classification.keys() + automatic_classification.keys()):
        m = ''
        a = ''
        try:
            m = manual_classification[key]
        except KeyError:
            pass
            
        try:
            a = automatic_classification[key]
        except KeyError:
            try:
                a = automatic_classification[key.split('; ')[0]]
            except:
                pass
        writer.writerow([key, m,a])

# %%
search_cache = {}

# %%
def taxon_search(string):
    try:
        return search_cache[string]
    except KeyError:
        ident = None
        response = urllib2.urlopen(taxonomy_api + "&term=" + string).read()
        xml = ET.fromstring(response)    
        for e in xml:
            if e.tag == 'Count':
                if int(e.text) > 0:
                    found = True
            if e.tag == 'IdList' and len(e) > 0:
                ident = e[0].text
        return ident

# %%
classify(taxon_search('Guinea-Pig'))
# Out:
# 'Other Mammal'

# %%
manual_bins = {}

# %%
manual_classification.values()[0:10]
# Out:
# [u'Mice',
#  u'Roundworms',
#  u'Humans',
#  u'Rats',
#  u'Rats',
#  u'Mice',
#  u'Rats',
#  u'Humans',
#  u'Rats',
#  u'Mice; Rats']

# %%
for key, value in manual_classification.iteritems():
    orgs = value.split(';')
    for org in orgs:
        org = org.strip()
        if org == 'Humans':
            org = 'Human'
        try:
            classification = classify(taxon_search(org))
            try:
                manual_bins[classification] += 1
            except KeyError:
                manual_bins[classification] = 1
        except TypeError:
            print org
# Out:
# Snails
# Guinea Pigs
# Fruit flies
# Guinea Pigs
# Sea Slugs
# Snails
# Guinea pigs
# Guinea pigs
# Guinea Pigs
# Sea slugs
# Snails
# Guinea Pigs
# Squirrels
# Guinea pigs

# %%
manual_bins_normed = { k:float(v)/sum(manual_bins.values()) for k,v in manual_bins.iteritems() }

# %%
journal_taxa['Journal of neuroscience research']
# Out:
# {'Amphibean': 0.0025012506253126563,
#  'Cat': 0.0030015007503751876,
#  'Fish': 0.0060030015007503752,
#  'Human': 0.17408704352176088,
#  'Macaque': 0.0010005002501250625,
#  'Mouse or Rat': 0.68034017008504255,
#  'Non-Craniata': 0.087543771885943006,
#  'Other Craniata': 0.013506753376688344,
#  'Other Mammal': 0.029514757378689343,
#  'Other Primate': 0.0025012506253126563}

# %%
manual_bins_normed
# Out:
# {'Amphibean': 0.003357314148681055,
#  'Cat': 0.0014388489208633094,
#  'Fish': 0.0023980815347721821,
#  'Human': 0.23549160671462829,
#  'Mouse or Rat': 0.73045563549160675,
#  'Non-Craniata': 0.0028776978417266188,
#  'Other Craniata': 0.011510791366906475,
#  'Other Mammal': 0.0095923261390887284,
#  'Other Primate': 0.0028776978417266188}

# %%
manual_values = {}

for k in keys:
    try:
        manual_values[k] = manual_bins_normed[k]
    except KeyError:
        manual_values[k] = 0.

# %%
manual_values
# Out:
# {'Amphibean': 0.003357314148681055,
#  'Cat': 0.0014388489208633094,
#  'Fish': 0.0023980815347721821,
#  'Human': 0.23549160671462829,
#  'Macaque': 0.0,
#  'Mouse or Rat': 0.73045563549160675,
#  'Non-Craniata': 0.0028776978417266188,
#  'Other Craniata': 0.011510791366906475,
#  'Other Mammal': 0.0095923261390887284,
#  'Other Primate': 0.0028776978417266188}

# %%
font = { 'size'   : 16}
matplotlib.rc('font', **font)    

keys = journal_taxa['Journal of neuroscience research'].keys()
values = [ journal_taxa['Journal of neuroscience research'][k] for k in keys ]
values_ = [ manual_values[k] for k in keys ]
 
width = 0.35

fig = plt.figure(figsize=(20,10), dpi=300)
ind = np.array(range(len(values)))
plt.bar(ind, np.array(values)*100, width, color='b', alpha=0.8, label='Automated')
plt.bar(ind+width, np.array(values_)*100, width, color='g', alpha=0.5, label='Manual')
plt.title('Journal of Neuroscience Research')
ax = fig.add_subplot(1, 1, 1)
ax.set_xticks(ind+width)
ax.set_xticklabels(keys)
plt.ylabel("Percent of Papers")
fig.autofmt_xdate(rotation=90)
plt.legend()
plt.savefig("/Users/erickpeirson/Model Organisms in Neuroscience/figures/JNR_comparison.png")

# %% [markdown]
# ## Modeling (ignore for now)

# %%
from vsm.corpus import Corpus
from vsm.corpus.util import corpusbuilders as cb
from vsm.model import tf, tfidf, lsa, ldagibbs, beaglecomposite, beaglecontext, beagleenvironment, beagleorder, ldacgsmulti
from vsm.viewer import ldagibbsviewer, tfidfviewer
from vsm.viewer import beagleviewer
import pickle

# %%
for i in xrange(len(aslist)):
    aslist[i].abstract = tokenize(str(strip_non_ascii(aslist[i].abstract)))

# %%
abstracts = [ tokenize(str(strip_non_ascii(p.abstract))) for p in aslist]

# %%
model_path = "/Users/erickpeirson/Desktop/MO"
filename = "ACSChemicalNeuroscience"

# %%
ec = cb.corpus_fromlist(abstracts, context_type='sentence')
#pickle.dump(ec, open(model_path+filename+"_ec.model", "w"))
print str(len(ec.words)) + " in unfiltered vocabulary"

cc = ec.apply_stoplist(stopwords.words())
#pickle.dump(cc, open(model_path+filename+"_cc.model", "w"))
print str(len(cc.words)) + " after stoplist applied"
    
be = beagleenvironment.BeagleEnvironment(ec)
be.train()
#pickle.dump(be, open(model_path+filename+"_be.model", "w"))
print "environment done"
    
ms = beaglecontext.BeagleContextSeq(cc, ec, be.matrix)
ms.train()
#pickle.dump(ms, open(model_path+filename+"_ms.model", "w"))
print "context done"
    
#od = beagleorder.BeagleOrderSeq(ec, be.matrix)
#od.train()
#pickle.dump(od, open(model_path+filename+"_od.model", "w"))
#print "order done"

#bc = beaglecomposite.BeagleComposite(cc, ms.matrix, ec, od.matrix)
#bc.train()
#pickle.dump(bc, open(model_path+filename+"_bc.model", "w"))
    
#bv = beagleviewer.BeagleViewer(cc, bc)
bv_x = beagleviewer.BeagleViewer(cc, ms)
#bv_o = beagleviewer.BeagleViewer(ec, od)
# Out:
# 3725 in unfiltered vocabulary
# Removing stop words
# Rebuilding corpus
# Recomputing token breaks: sentence
# 3613 after stoplist applied
# environment done
# context done
# order done
# Summing context and order vectors

# %%
bv_x.sim_word_word(['mice'])
# Out:
# LabeledColumn([('mice', 0.0), ('fmr1', 0.39537694421526803),
#        ('wt', 0.3982482347336754), ..., ('needs', 1.5839230272504048),
#        ('track', 1.5842801854071311), ('concordia', 1.5866373526739659)],
#       dtype=[('word', 'S69'), ('value', '<f8')])

# %%
print bv_x.simmat_words(['mouse', 'rat', 'human', 'alzheimers', 'schizophrenia', 'model'])
# Out:
# [[ 0.          1.33984592  1.41831421  1.22557178  1.46870851  1.2670304 ]
#  [ 1.33984592  0.          0.59584485  1.30687935  1.37101213  1.17917013]
#  [ 1.41831421  0.59584485  0.          1.18388858  1.44428624  1.1937317 ]
#  [ 1.22557178  1.30687935  1.18388858  0.          1.26959225  1.27625323]
#  [ 1.46870851  1.37101213  1.44428624  1.26959225  0.          1.21293794]
#  [ 1.2670304   1.17917013  1.1937317   1.27625323  1.21293794  0.        ]]

# %%
'alzheimers' in vocabulary
# Out:
# True

# %%
bv_o.sim_word_word(['mice'])
# Out:
# LabeledColumn([('mice', 0.0), ('vitro', 1.4722014624406763),
#        ('involved', 1.47488639400319), ..., ('pace', 1.643048032141857),
#        ('technique', 1.6526411874742368), ('possibly', 1.6650815158136467)],
#       dtype=[('word', 'S69'), ('value', '<f8')])

# %%
bv.sim_word_word(['mice'])
# Out:
# LabeledColumn([('mice', 0.0), ('wt', 1.0511152779834834),
#        ('ko', 1.0689742055417488), ..., ('mglu5', 1.6105116707649019),
#        ('trial', 1.6109934123852057),
#        ('n4chloro213dioxo13dihydro2hisoindol2ylmethylphenyl2hydroxybenzamide', 1.6217134659275432)],
#       dtype=[('word', 'S69'), ('value', '<f8')])

# %%
bv_x.sim_word_word(['rabbits'])
# Out:
# LabeledColumn([('rabbits', 0.0), ('enhancement', 0.07975901643024572),
#        ('sonications', 0.08130658689085456), ...,
#        ('3propionic', 1.6032105473240919), ('rgc5', 1.6039426514905122),
#        ('cloning', 1.608294439328732)],
#       dtype=[('word', 'S69'), ('value', '<f8')])

# %%
bv_x.sim_word_word(['monkeys'])
# Out:
# LabeledColumn([('monkeys', 0.0), ('signaltonoise', 0.07707319688605105),
#        ('rhesus', 0.07726469786466977), ...,
#        ('lucido2009', 1.5952180681783756),
#        ('neurosci29', 1.596953325611372),
#        ('gopalakrishnan2010', 1.598285513697295)],
#       dtype=[('word', 'S69'), ('value', '<f8')])

# %%