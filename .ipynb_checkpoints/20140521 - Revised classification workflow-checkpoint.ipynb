# %%
from nltk.corpus import stopwords
import string
import rdflib
import urllib2
import xml.etree.ElementTree as ET
import os
import subprocess
import pickle
import matplotlib.pyplot as plt
import tempfile
from collections import Counter
import csv

# %%
import re

# %%
def tokenize(s):
    s = s.translate(string.maketrans("",""), string.punctuation)
    return s.lower().split()

# %%
def remove_stopwords(t):
    return [ word for word in t if word not in stopwords.words() and word != 'ab' ]

# %%
def strip_non_ascii(string):
    ''' Returns the string without non ASCII characters'''
    stripped = (c for c in string if 0 < ord(c) < 127)
    return ''.join(stripped)

# %%
def remove_integers(t):
    new_t = []
    for word in t:
        try:
            int(word)
        except ValueError:
            new_t.append(word)
    return new_t

# %%
class dictionary:
    """
    A two-way index for integer/string pairs.
    """
    def __init__(self):
        self.by_str = {}
        self.by_int = {}
        
    def __setitem__(self, key, value):
        if type(key) == str:
            self.by_str[key] = value
            self.by_int[value] = key
        if type(key) == int:
            self.by_int[key] = value
            self.by_str[value] = key
    
    def __getitem__(self, key):
        if type(key) == str:
            return self.by_str[key]
        if type(key) == int:
            return self.by_int[key]

# %%
class paper:
    """
    Describes a minimal PubMed entry.
    """
    def __init__(self, uri, abstract, journal, title, date):
        self.uri = uri
        self.abstract = abstract
        self.journal = journal
        self.title = title
        self.date = date

# %%
def to_path(uri):
    return str(uri).replace('/', '___')

# %%
def to_uri(path):
    return str(path).replace('___', '/')

# %%
orgpath = '/Users/erickpeirson/Programming/Model-Organisms-in-Neuroscience/data'

# %%
datapath = '/Users/erickpeirson/Programming/Model-Organisms-in-Neuroscience/data/RDF'

# %%
taxonomy_api = "http://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=taxonomy"
taxonomy_api_get = "http://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=taxonomy"

# %% [markdown]
# ## Load Data

# %%
g = rdflib.Graph()
for filename in os.listdir(datapath):
    if filename.split('.')[-1] == 'rdf':
        g.load(datapath+"/"+filename)

# %% [markdown]
# ### `asdict`: Index by subject

# %%
asdict = {}    # Index by subject.
for s,p,o in g:  # Subject, predicate, and object in RDF triple.
    try:
        asdict[s][p] = o
    except KeyError:
        asdict[s] = {}
        asdict[s][p] = o

# %% [markdown]
# ### `aslist`: Generate a list of `paper`s

# %%
aslist = []
for key, value in asdict.iteritems():
    type_key = rdflib.term.URIRef(u'http://www.w3.org/1999/02/22-rdf-syntax-ns#type')
    article_key = rdflib.term.URIRef(u'http://purl.org/net/biblio#Article')
    dkey = rdflib.term.URIRef(u'http://purl.org/dc/elements/1.1/date')
    if value[type_key] == article_key:
        try:
            m = re.match('(\w+)?\s?([0-9]{1,2})?\,?\s?([0-9]{4})', value[dkey])
            if m is None:
                print value[dkey]
            date = (m.group(3), m.group(1), m.group(2))
            p = paper(key, value[rdflib.term.URIRef(u'http://purl.org/dc/terms/abstract')], value[rdflib.term.URIRef(u'http://purl.org/dc/terms/isPartOf')], value[rdflib.term.URIRef(u'http://purl.org/dc/elements/1.1/title')], date)
            aslist.append(p)
        except KeyError:
            pass

# %%
len(aslist) # number of abstracts
# Out:
# 29259

# %%
aslist[0].date
# Out:
# (u'2009', u'Sep', u'20')

# %% [markdown]
# ## LINNAEUS NER & classification via NCBI Taxonomy
#
# ### Named Entity Recognition
# * [LINNAEUS](http://linnaeus.sourceforge.net/)
#
# ### Classification logic:
# * For each paper in a journal:
#     * For each unique taxon in that paper,
#         * If the taxon group is human:
#             * If human is the only taxon group in that paper, or if the number of hits for human is greater than 1:
#                 * Increment the human group
#         * Otherwise,
#             * Increment the taxon group

# %% [markdown]
# ### Globals

# %%
classified = {}    # For caching classification results.

# %%
orgs_in_paper = { p.uri:[] for p in aslist }

# %%
taxa_in_paper = { p.uri:Counter() for p in aslist }
taxa_hits_in_paper = { p.uri:Counter() for p in aslist }

# %%
taxa_in_journal = {}

# %% [markdown]
# ### Methods

# %%
def merge(result):
    """
    Uses NCBI Taxonomy XML response to decide to which higher-level
    taxonomic group a taxon belongs.

    Parameters
    ----------
    result : ET XML object
        NCBI Taxonomy response.
    
    Returns
    -------
    str
        Taxon category (e.g. 'Human', 'Mouse or Rat', etc).
    """
    
    # All higher-level taxonomic groups to which this taxon belongs.
    taxa = [ tax.text for tax in result.findall('.//TaxId') ]

    if '33208' in taxa and '7742' not in taxa:    # Any metazoan that is not a vertebrate.
        return 'Invertebrate'
    if '89593' in taxa: # Craniata
        if '7898' in taxa or '7894' in taxa or '7878' in taxa: # Fishes
            return 'Fish'
        elif '8782' in taxa:    # Aves
            return 'Bird'
        elif '1294634' in taxa or '8505' in taxa or '8509' in taxa or '8459' in taxa: # Crocodylia (in Amniota); Sphenodontia; Squamata; Testudines
            return 'Reptile'
        elif '8292' in taxa: # Amphibeans
            return 'Amphibean'
        elif '40674' in taxa: # Mammals
            if '9681' in taxa: # Cats
                return 'Cat'
            elif '10066' in taxa: # Mice & rats
                return 'Mouse or Rat'
            elif '9443' in taxa: # Primates
                if '9605' in taxa: # Human
                    return 'Human'
                elif '9539' in taxa: # Macaque
                    return 'Macaque'
                else:
                    return 'Other Primate'
            else: # Other mammals
                return 'Other Mammal'
        # Remainder
        return 'Other Craniate'
    else: # Not in Craniata
        return 'Non-Craniate'

# %%
def classify(taxon):
    """
    Yields the higher-level taxonomic group to which taxon belongs.

    Retrieves data for taxon from NCBI Taxonomy, then passes the result
    to merge() to classify. Uses classified (dict) to cache results.

    Parameters
    ----------
    taxon : str
        NCBI Taxonomy ID.

    Returns
    -------
    merged : str
        Taxon category (e.g. 'Human', 'Mouse or Rat', etc).
    """
    try:
        return classified[taxon]
    except KeyError:
        response = urllib2.urlopen(taxonomy_api_get + "&id=" + taxon).read()
        xml = ET.fromstring(response)
        classified[taxon] = merge(xml)
        return classified[taxon]

# %%
def find_names_batch(papers, linnaeus_path="/Applications/linnaeus/bin/linnaeus-2.0.jar", outpath='./'):
    """
    Named Entity Recognition step.

    Generates a temporary directory containing one text file per paper (title+abstract),
    and throws LINNAEUS at it.

    Parameters
    ----------
    papers : list
        A list of :class:`paper` objects.
    linnaeus_path : str
        Path to LINNAEUS .jar file.
    outpath : str
        Target directory for NER results.

    Returns
    -------
    resultspath : str
        Path to CSV-formated NER results file.
    """
    temp = tempfile.mkdtemp()
    for paper in papers:
        filepath = '{0}/{1}.txt'.format(temp, to_path(paper.uri))
        with open(filepath, 'w') as f:
            f.write(str(strip_non_ascii(paper.title)) + "\n")
            f.write(str(strip_non_ascii(paper.abstract)) + "\n")

    resultspath = '{0}/orgnames.csv'.format(outpath)    # CSV results will go here.
    
    # Call LINAEUS.
    subprocess.call(['java', '-jar', linnaeus_path, '--textDir', temp, '--out', resultspath ])

    del temp    # Cleanup.
    
    return resultspath

# %%
def handle_result_taxon(result):
    """
    Parse the taxon ID porition of LINNAEUS NER result.

    If multiple possible taxa are suggested, chooses the one with the greater
    confidence level.

    Parameters
    ----------
    result : list
        A CSV-parsed row from the LINNAEUS NER results file.

    Returns
    -------
    str
        NCBI Taxonomy ID for NER-matched taxon.
    """
    taxa = [ r.split(':')[-1] for r in result[0].split('|') ]
    if len(taxa) > 1:   
        confidence = []
        ids = []        
        for t in taxa:
            t_c = t.split('?')
            confidence.append(t_c[1])
            ids.append(t_c[0])
    
        return ids[confidence.index(max(confidence))]
    else:
        return taxa[0].split('?')[0]

# %%
def handle_result(result):
    """
    Assigns taxon matches from NER to each respective paper.

    Parameters
    ----------
    result : list
        A CSV-parsed row from the LINNAEUS NER results file.        
    """    
    taxon = handle_result_taxon(result)
    uri = rdflib.term.URIRef(to_uri(result[1]))
    orgs_in_paper[uri].append(taxon)

# %%
def handle_paper_taxa(uri):
    """
    Applies logic for assigning taxon-group hits to journals.

    Humans are treated slightly differently than the rest. To accrue a hit
    for 'Human', it must be the only hit for that paper, or there must have
    been at least two hits for that paper.

    Parameters
    ----------
    uri : str
        URI belonging to a :class:`.paper`.

    Returns
    -------
    to_increment : dict
        Keys are taxon-groups to increment for corresponding journal,
        values are the amount to increment each taxon-group.
    """
    to_increment = {}
    taxa = taxa_in_paper[uri]
    taxon_hits = taxa_hits_in_paper[uri]
    
    for taxon, count in taxa.iteritems():
        if taxon == 'Human':
            if len(taxa) == 1 or taxon_hits['Human'] > 1:
                to_increment['Human'] = 1
        else:
            to_increment[taxon] = count
    return to_increment

# %% [markdown]
# ### Execution

# %%
resultpath = find_names_batch(aslist)    # <-- The action.

# %%
# Read the CSV-formatted NER results file from LINNAEUS.
results = []
with open(resultpath, 'r') as f:
    reader = csv.reader(f, delimiter='\t')
    for row in reader:
        results.append(row)

# %%
# Assign taxon matches to papers.
for result in results[1:]:
    handle_result(result)

# %%
import time

# %%
missed = []
# Classify taxon matches, and accrue to papers.
for uri,ts in orgs_in_paper.iteritems():
    for t in ts:    # Count number of taxon-group hits in title and abstract.
        try:
            c = classify(t)
            taxa_hits_in_paper[uri][c] += 1
        except:
            missed.append(t)
    for t in set(ts):    # Count number of unique taxon-group hits.
        try:
            c = classify(t)
            taxa_in_paper[uri][c] += 1
        except:
            pass

# %%
len(orgs_in_paper), len(missed)
# Out:
# (29259, 28)

# %%
# Index journal names by the URIs of their papers.
journal = {}
for pap in aslist:
    # Get object of dc.title triple for paper's journal (pap.journal is a journal URI).
    title = str(asdict[pap.journal][rdflib.term.URIRef(u'http://purl.org/dc/elements/1.1/title')])
    journal[pap.uri] = title.lower()

# %%
# Assign taxon-group hits to journals.
for pap in aslist:
    ti = handle_paper_taxa(pap.uri)
    jtitle = journal[pap.uri]
    for k,v in ti.iteritems():
        try:
            taxa_in_journal[jtitle][k] += v
        except KeyError:
            taxa_in_journal[jtitle] = Counter()
            taxa_in_journal[jtitle][k] += v

# %% [markdown]
# ## Abstract contents

# %%
import string

# %%
''.join(list(set(string.punctuation) - set('-')))
# Out:
# '!#"%$\'&)(+*,/.;:=<?>@[]\\_^`{}|~'

# %%
aslist[0].abstract
# Out:
# rdflib.term.Literal(u"The sense of taste is crucial in an animal's determination as to what is edible and what is not. This gustatory function is especially important in goldfish, who utilize a sophisticated oropharyngeal sorting mechanism to separate food from substrate material. The computational aspects of this detection are carried out by the medullary vagal lobe, which is a large, laminated structure combining elements of both the gustatory nucleus of the solitary tract and the nucleus ambiguus. The sensory layers of the vagal lobe are coupled to the motor layers via a simple reflex arc. Details of this reflex circuit were investigated with histology and calcium imaging. Biocytin injections into the motor layer labeled vagal reflex interneurons that have radially directed dendrites ramifying within the layers of primary afferent terminals. Axons of reflex interneurons extend radially inward to terminate onto both vagal motoneurons and small, GABAergic interneurons in the motor layer. Functional imaging shows increases in intracellular Ca++ of vagal motoneurons following electrical stimulation in the sensory layer. These responses were suppressed under Ca(++)-free conditions and by interruption of the axons bridging between the sensory and motor layers. Pharmacological experiments showed that glutamate acting via (+/-)-alpha-amino-3-hydroxy- 5-ethylisoxazole-4-propioinc acid (AMPA)/kainate and N-methyl-D-aspartic acid (NMDA) receptors mediate neurotransmission between reflex interneurons and vagal motoneurons. Thus, the vagal gustatory portion of the viscerosensory complex is linked to branchiomotor neurons of the pharynx via a glutamatergic interneuronal system.")

# %%
def strip_punctuation(s):
    return ''.join([ w for w in s if w not in list(set(string.punctuation) - set('-')) ])

# %%
strip_punctuation('asdf.fsa3-aaa;')
# Out:
# 'asdffsa3-aaa'

# %%
def process_abstract(abst):
    sents = unicode(abst).lower().split('. ')
    return [ strip_punctuation(s).split(' ') for s in sents ]

# %%
processed_abstracts = {}
for p in aslist:
    processed_abstracts[p.uri] = process_abstract(p.abstract)

# %%
all_sentences = [ sent for abst in processed_abstracts.values() for sent in abst ]

# %%
from gensim.models import Word2Vec, Phrases

# %%
phrases = Phrases(all_sentences)

# %%
all_sentences_phrased = { k:[ phrases[sent] for sent in abst ] for k,abst in processed_abstracts.iteritems() }

# %%
wordcounts_by_paper = {}
global_counts = Counter()
for k,sentences in all_sentences_phrased.iteritems():
    counts = Counter()
    for sent in sentences:
        for word in sent:
            counts[word] += 1
            global_counts[word] += 1
    wordcounts_by_paper[k] = counts

# %%
plt.hist(global_counts.values())
plt.show()

# %%
len(global_counts)
# Out:
# 126797

# %%
from nltk.corpus import stopwords
stoplist = set(stopwords.words())

# %%
words_pared = list(set([ w for w,c in global_counts.iteritems() if c > 10 ]) - stoplist)

# %%
papers_lim = [ p for p in aslist if int(p.date[0]) < 2011 ]

# %%
N_papers = len(papers_lim)

# %%
taxa_in_paper[aslist[0].uri]
# Out:
# Counter({'Fish': 1})

# %%
f_word = Counter()
f_org = Counter()
f_word_org = Counter()
for paper in papers_lim:
    counts = wordcounts_by_paper[paper.uri]
    for word in list(set(words_pared) & set(counts.keys())):
        f_word[word] += 1.
        for org in taxa_in_paper[paper.uri].keys():
            f_word_org[(word,org)] += 1
    for org in taxa_in_paper[paper.uri].keys():
        f_org[org] += 1.

# %%
p_word = { k:float(c)/N_papers for k,c in f_word.iteritems() }
p_org = { k:float(c)/N_papers for k,c in f_org.iteritems() }
p_word_org = { k:float(c)/N_papers for k,c in f_word_org.iteritems() }

# %%
def _nPMI(p_ij, p_i, p_j):
    return ( np.log( p_ij/(p_i*p_j) ) ) / ( -1* np.log(p_ij) )

# %%
plt.hist(p_word_org.values())
plt.yscale('log')

# %%
nPMI = { t:[] for t in tkeys }
for pair,p_wo in p_word_org.iteritems():
    w,o = pair
    if o in tkeys and p_wo > 2./N_papers:
        p_w = p_word[w]
        p_o = p_org[o]
        n = _nPMI(p_wo, p_w, p_o)
        if n > 0.2:
            nPMI[o].append((w,n))
            print pair,p_wo,p_w,p_o, n
# Out:
# (u'spatially', 'Cat') 0.000461893764434 0.0084562089181 0.0104459051341 0.215388812938
# (u'eph_receptor', 'Invertebrate') 0.000106590868716 0.000604014922722 0.0213181737431 0.231081982225
# (u'snail', 'Invertebrate') 0.000319772606147 0.00039083318529 0.0213181737431 0.453226861245
# (u'gut', 'Invertebrate')
#  0.000177651447859 0.00106590868716 0.0213181737431 0.238132282134
# (u'ribbon_synapses', 'Fish') 0.000106590868716 0.00127909042459 0.0130040859833 0.203092159139
# (u'vestibular_system', 'Other Mammal') 0.000142121158287 0.000817196660153 0.0193284775271 0.247998408177
# (u'staining_intensity', 'Other Mammal') 0.000177651447859 0.00095931781844 0.0193284775271 0.261678865284
# (u'judging', 'Invertebrate')
#  0.000106590868716 0.000497424054006 0.0213181737431 0.252309309034
# (u'lfps', 'Cat') 0.000177651447859 0.000852726949725 0.0104459051341 0.346576859841
# (u'step_toward', 'Bird') 0.000106590868716 0.000639545212293 0.0119026470066 0.288550957151
# (u'populations', 'Reptile') 0.000106590868716 0.0206786285308 0.000710605791437 0.216643722944
# (u'medial_vestibular', 'Amphibean')
#  0.000177651447859 0.000710605791437 0.00461893764434 0.462186291238
# (u'bicuculline', 'Other Mammal') 0.000213181737431 0.00159886303073 0.0193284775271 0.228461992321
# (u'binding_affinity', 'Invertebrate')
#  0.000106590868716 0.000426363474862 0.0213181737431 0.269162801149
# (u'taxa', 'Fish') 0.000106590868716 0.00103037839758 0.0130040859833 0.226732109724
# (u'amplify', 'Cat') 0.000177651447859 0.00177651447859 0.0104459051341 0.261584297255
# (u'term', 'Other Primate') 0.000106590868716 0.00419257416948 0.00383727127376 0.206736872849
# (u'hair_cell', 'Bird') 0.000284242316575 0.00238052940131 0.0119026470066 0.2823699205
# (u'rewards', 'Macaque') 0.000213181737431 0.00465446793391 0.00671522472908 0.227121389978
# (u's100beta', 'Other Mammal') 0.000106590868716 0.000639545212293 0.0193284775271 0.235545103397
# (u'their_cognate', 'Invertebrate') 0.000106590868716 0.000639545212293 0.0213181737431 0.224832779315
# (u'als_animal', 'Human') 0.000213181737431 0.000213181737431 0.182838870137 0.201002783956
# (u'under_anesthesia', 'Cat') 0.000106590868716 0.000675075501865 0.0104459051341 0.296913001315
# (u'cjd', 'Other Mammal') 0.000142121158287 0.000888257239297 0.0193284775271 0.238586149115
# (u'caudomedial', 'Fish') 0.000106590868716 0.000817196660153 0.0130040859833 0.252075278364
# (u'conspecific', 'Bird')
#  0.000213181737431 0.00110143897673 0.0119026470066 0.32990017069
# (u'5-bromo-2-deoxyuridine_brdu', 'Fish') 0.000106590868716 0.000639545212293 0.0130040859833 0.278874832011
# (u'multiunit', 'Cat') 0.000248712027003 0.000781666370581 0.0104459051341 0.41165495634
# (u'receives', 'Other Primate') 0.000142121158287 0.00529401314621 0.00383727127376 0.219593522634
# (u'very_strong', 'Other Mammal') 0.000142121158287 0.00056848463315 0.0193284775271 0.288963802886
# (u'coiled-coil_domain', 'Invertebrate') 0.000106590868716 0.000284242316575 0.0213181737431 0.313492822983
# (u'spatio-temporal', 'Bird') 0.000106590868716 0.00110143897673 0.0119026470066 0.229116781103
# (u'spatial_summation', 'Cat') 0.000106590868716 0.000461893764434 0.0104459051341 0.338403089807
# (u'resolves', 'Macaque') 0.000106590868716 0.000746136081009 0.00671522472908 0.334276891202
# (u'directs', 'Bird') 0.000106590868716 0.00142121158287 0.0119026470066 0.201249083574
# (u'ovo', 'Bird') 0.00039083318529 0.000461893764434 0.0119026470066 0.543368874212
# (u'ontogenetic', 'Fish') 0.000106590868716 0.000781666370581 0.0130040859833 0.256935246745
# (u'saccule', 'Amphibean') 0.000106590868716 0.000497424054006 0.00461893764434 0.419520054088
# (u'ray-finned_fishes', 'Fish') 0.000213181737431 0.000248712027003 0.0130040859833 0.495464317787
# (u'semicircular_canals', 'Fish') 0.000142121158287 0.000497424054006 0.0130040859833 0.348773875773
# (u'pkc-1', 'Invertebrate') 0.000106590868716 0.000106590868716 0.0213181737431 0.420728146892
# (u'species-specific', 'Bird') 0.000177651447859 0.00156333274116 0.0119026470066 0.261269627102
# ...
# (u'border', 'Cat') 0.000248712027003 0.00323325635104 0.0104459051341 0.240576477349
# (u'horseradish_peroxidase', 'Amphibean') 0.000106590868716 0.00095931781844 0.00461893764434 0.347713502535
# (u'left-right', 'Other Primate') 0.000106590868716 0.000994848108012 0.00383727127376 0.364007754115
# (u'thalamic_input', 'Cat') 0.000106590868716 0.000817196660153 0.0104459051341 0.276024686518
# (u'slowing', 'Amphibean') 0.000106590868716 0.00291348374489 0.00461893764434 0.226259302822
# (u'tangential', 'Bird') 0.000142121158287 0.0020252265056 0.0119026470066 0.200278979484
# (u'membrane_conductance', 'Other Mammal') 0.000106590868716 0.000781666370581 0.0193284775271 0.213605518132
# (u'human_prion', 'Human') 0.000710605791437 0.000710605791437 0.182838870137 0.234385150545
# (u'histological_examination', 'Bird') 0.000142121158287 0.000888257239297 0.0119026470066 0.293313317396
# (u'cresyl_violet', 'Bird') 0.000106590868716 0.000497424054006 0.0119026470066 0.31602748687
# (u'adult-like', 'Other Mammal') 0.000177651447859 0.000817196660153 0.0193284775271 0.280246310872
# (u'ashs', 'Invertebrate') 0.000142121158287 0.000142121158287 0.0213181737431 0.434390892033
# (u'limitation', 'Cat') 0.000106590868716 0.000817196660153 0.0104459051341 0.276024686518

# %%
topw,c = zip(*nPMI['Fish'])

# %%
corder = [np.argsort(c)[::-1]]
array(zip(array(topw)[corder], array(c)[corder])[0:200])
# Out:
# array([[u'zebrafish', u'0.85283459227'],
#        [u'goldfish', u'0.646322948477'],
#        [u'adult_zebrafish', u'0.618038381156'],
#        [u'teleost_fish', u'0.618038381156'],
#        [u'fish', u'0.610278819878'],
#        [u'larval_zebrafish', u'0.590433359596'],
#        [u'zebrafish_danio', u'0.581126876378'],
#        [u'rerio', u'0.581126876378'],
#        [u'teleost', u'0.567194203595'],
#        [u'teleosts', u'0.561303379308'],
#        [u'zebrafish_retina', u'0.559583695935'],
#        [u'zebrafish_embryos', u'0.559583695935'],
#        [u'transgenic_zebrafish', u'0.553378939654'],
#        [u'burtoni', u'0.539580690313'],
#        [u'posterior_tuberculum', u'0.534738450866'],
#        [u'lateral_line', u'0.529936302621'],
#        [u'carp', u'0.517373548888'],
#        [u'dpf', u'0.513699738852'],
#        [u'lungfish', u'0.507151621995'],
#        [u'm-cell', u'0.507151621995'],
#        [u'eod', u'0.507151621995'],
#        [u'hpf', u'0.504470707843'],
#        [u'mauthner', u'0.503834463668'],
#        [u'stargazer', u'0.502854216639'],
#        [u'weakly_electric', u'0.495688608874'],
#        [u'neuromasts', u'0.495464317787'],
#        [u'ray-finned_fishes', u'0.495464317787'],
#        [u'rhombencephalic', u'0.493888676134'],
#        [u'lobe_ell', u'0.492798668348'],
#        [u'electric_organ', u'0.492798668348'],
#        [u'pretectal', u'0.483730958709'],
#        [u'octaval_nucleus', u'0.481741645631'],
#        [u'toral', u'0.481741645631'],
#        [u'tetrapods', u'0.479930029823'],
#        [u'electroreceptors', u'0.47966807756'],
#        [u'larvae', u'0.47790813031'],
#        [u'optic_tectum', u'0.476261011628'],
#        [u'fishes', u'0.475164196079'],
#        [u'octaval', u'0.463891221188'],
#        [u'vertebrates', u'0.460782100587'],
#        [u'hindbrain', u'0.458584461461'],
#        [u'morpholino', u'0.454815941003'],
#        [u'electrosensory', u'0.453325304358'],
#        [u'ell', u'0.45327107029'],
#        [u'lungfishes', u'0.44441831183'],
#        [u'fin', u'0.44441831183'],
#        [u'whole-mount', u'0.439487996487'],
#        [u'dp', u'0.431703144926'],
#        [u'dorsal_telencephalic', u'0.431408473893'],
#        [u'vertebrate', u'0.425551743384'],
#        [u'fgf_signaling', u'0.423632012829'],
#        [u'preoptic_area', u'0.422319211477'],
#        [u'mechanosensory_hair', u'0.422234406422'],
#        [u'fiber_connections', u'0.422234406422'],
#        [u'vivo_time-lapse', u'0.422234406422'],
#        [u'swimming', u'0.419073953322'],
#        [u'other_vertebrates', u'0.417300263814'],
#        [u'gastrulation', u'0.411944265961'],
#        [u'reticulospinal_neurons', u'0.401476210617'],
#        [u'm\xfcller_glia', u'0.400292714013'],
#        [u'torus_semicircularis', u'0.398799211222'],
#        [u'proneural', u'0.398648714834'],
#        [u'prey', u'0.387455218552'],
#        [u'subpallium', u'0.385463322274'],
#        [u'placode', u'0.383625786174'],
#        [u'telencephalon', u'0.383329733402'],
#        [u'pallial', u'0.380942541919'],
#        [u'many_similarities', u'0.37599666247'],
#        [u'primordia', u'0.37599666247'],
#        [u'they_migrate', u'0.37599666247'],
#        [u'escapes', u'0.37599666247'],
#        [u'reticular_formation', u'0.375682123631'],
#        [u'dd', u'0.375636512037'],
#        [u'primordium', u'0.375636512037'],
#        [u'tract-tracing_methods', u'0.375636512037'],
#        [u'dorsal_telencephalon', u'0.374776173392'],
#        [u'tectum', u'0.373130310472'],
#        [u'pallium', u'0.368313333091'],
#        [u'rostrolateral', u'0.36816304519'],
#        [u'retinotectal_projection', u'0.367534875679'],
#        [u'mormyrid', u'0.367534875679'],
#        [u'daughter_cell', u'0.367534875679'],
#        [u'oculomotor_nucleus', u'0.366174668964'],
#        [u'rhombencephalon', u'0.366174668964'],
#        [u'ventral_telencephalic', u'0.366174668964'],
#        [u'retinotectal', u'0.365502791228'],
#        [u'swim', u'0.361142802189'],
#        [u'pretectum', u'0.361142802189'],
#        [u'dl', u'0.361142802189'],
#        [u'vagal', u'0.360607106257'],
#        [u'stratum', u'0.359999655764'],
#        [u'model_organism', u'0.359999655764'],
#        [u'ventral_telencephalon', u'0.357379495943'],
#        [u'poa', u'0.357139310805'],
#        [u'ciliated', u'0.357139310805'],
#        [u'larval_stages', u'0.357139310805'],
#        [u'amphibians', u'0.35620204528'],
#        [u'larval', u'0.355925320691'],
#        [u'fill', u'0.354741186528'],
#        [u'ventralis', u'0.354657504882'],
#        [u'invagination', u'0.354657504882'],
#        [u'persistent_firing', u'0.354657504882'],
#        [u'macula', u'0.354657504882'],
#        [u'otic', u'0.354657504882'],
#        [u'sdf1', u'0.354657504882'],
#        [u'rod-cone', u'0.354657504882'],
#        [u'african', u'0.351973775444'],
#        [u'docked_vesicles', u'0.348773875773'],
#        [u'rhombic_lip', u'0.348773875773'],
#        [u'axonal_pathfinding', u'0.348773875773'],
#        [u'semicircular_canals', u'0.348773875773'],
#        [u'medial_longitudinal', u'0.348263035471'],
#        [u'high-speed', u'0.348263035471'],
#        [u'habenula', u'0.348263035471'],
#        [u'corpus', u'0.347888864727'],
#        [u'diencephalic', u'0.345247329234'],
#        [u'androgens', u'0.343937909917'],
#        [u'olfactory_placode', u'0.343138304176'],
#        [u'utricular', u'0.343138304176'],
#        [u'telencephalic', u'0.342614823659'],
#        [u'sheet', u'0.340985842079'],
#        [u'distributed_along', u'0.340985842079'],
#        [u'pcna', u'0.340237812496'],
#        [u'extant', u'0.340237812496'],
#        [u'medialis', u'0.333700623094'],
#        [u'hcs', u'0.333700623094'],
#        [u'wrapping', u'0.333700623094'],
#        [u'lateralis', u'0.332717919617'],
#        [u'replenished', u'0.332717919617'],
#        [u'nonmammalian_vertebrates', u'0.332717919617'],
#        [u'cone', u'0.329131241801'],
#        [u'facial_nerve', u'0.326857211779'],
#        [u'elaborated', u'0.326857211779'],
#        [u'transgenic_lines', u'0.326857211779'],
#        [u'periodically', u'0.323204853845'],
#        [u'settle', u'0.323204853845'],
#        [u'proneural_gene', u'0.323204853845'],
#        [u'beat', u'0.323204853845'],
#        [u'pretectal_nucleus', u'0.323204853845'],
#        [u'genus', u'0.323204853845'],
#        [u'dorsal_thalamus', u'0.322618940427'],
#        [u'aromatase', u'0.321210775603'],
#        [u'australian', u'0.320405071967'],
#        [u'cone_photoreceptors', u'0.319266416582'],
#        [u'inner_nuclear', u'0.317584170828'],
#        [u'subpallial', u'0.315674889708'],
#        [u'gnrh', u'0.314950440861'],
#        [u'exponential', u'0.314453681653'],
#        [u'uniformly_distributed', u'0.314453681653'],
#        [u'semicircular_canal', u'0.314453681653'],
#        [u'transparent', u'0.314453681653'],
#        [u'social_environment', u'0.314453681653'],
#        [u'integrators', u'0.314453681653'],
#        [u'm\xfcller_glial', u'0.314453681653'],
#        [u'orthologs', u'0.314301871275'],
#        [u'lineage_tracing', u'0.314301871275'],
#        [u'labeled_terminals', u'0.314301871275'],
#        [u'exclusively_expressed', u'0.314301871275'],
#        [u'pituitary', u'0.312424908324'],
#        [u'diencephalon', u'0.311934401641'],
#        [u'embryos', u'0.310561545368'],
#        [u'ancestral', u'0.31024979998'],
#        [u'tectal', u'0.309847047296'],
#        [u'retract', u'0.308511796209'],
#        [u'vertebrate_retina', u'0.308511796209'],
#        [u'preoptic', u'0.307571671442'],
#        [u'xenopus', u'0.307372948536'],
#        [u'escape', u'0.307254879084'],
#        [u'saccule', u'0.30635136173'],
#        [u'h3', u'0.30635136173'],
#        [u'model_organisms', u'0.30635136173'],
#        [u'neurod', u'0.30635136173'],
#        [u'gustatory', u'0.305404786071'],
#        [u'socially', u'0.305074122666'],
#        [u'inner_ear', u'0.303733944726'],
#        [u'screens', u'0.303004278776'],
#        [u'ancient', u'0.303004278776'],
#        [u'stargazin', u'0.303004278776'],
#        [u'egr-1', u'0.298808282342'],
#        [u'pit', u'0.298808282342'],
#        [u'postembryonic', u'0.298808282342'],
#        [u'epithelium_rpe', u'0.298808282342'],
#        [u'interpeduncular_nucleus', u'0.298808282342'],
#        [u'dii', u'0.29850042714'],
#        [u'mitral_cells', u'0.297948012883'],
#        [u'neural_tube', u'0.295700909041'],
#        [u'nuclear_antigen', u'0.295345678065'],
#        [u'cones', u'0.294736006592'],
#        [u'retina', u'0.294150177099'],
#        [u'homologous', u'0.293782404759'],
#        [u'bipolar_cells', u'0.292808514762'],
#        [u'using_time-lapse', u'0.292735228386'],
#        [u'vv', u'0.292735228386'],
#        [u'useful_marker', u'0.291752202808'],
#        [u'bioluminescence', u'0.291752202808'],
#        [u'comparative_analysis', u'0.291752202808'],
#        [u'ascending_projections', u'0.291752202808'],
#        [u'aquatic', u'0.291752202808'],
#        [u'ventral_midline', u'0.291752202808'],
#        [u'immunohistochemical_localization', u'0.291752202808']],
#       dtype='<U32')

# %% [markdown]
# ## Change over time

# %%
tkeys = ['Human', 
         'Macaque', 
         'Other Primate',
         'Mouse or Rat',
         'Cat',
         'Other Mammal',
         'Bird',
         'Reptile',
         'Amphibean',
         'Fish',
         'Invertebrate']

# %%
by_date = {}
for p in aslist:
    if p.date[0] not in by_date:
        by_date[p.date[0]] = { t:0 for t in tkeys }
    for c,v in taxa_hits_in_paper[p.uri].iteritems():
        if c in by_date[p.date[0]]:
            by_date[p.date[0]][c] += v

# %%
years = sorted(by_date.keys())[0:6]
orgs = sorted(tkeys)

# %%
timeseries = np.zeros((11,6))
for i in xrange(len(years)):
    timeseries[:,i] = array([ by_date[years[i]][o] for o in orgs ])

# %%
timechange = np.zeros((11,5))
for i in xrange(1,len(years)):
    year = years[i]
    timechange[:,i-1] = (timeseries[:,i] - timeseries[:,i-1])/timeseries[:,i-1]

# %%
plt.figure(figsize=(15,10))
for i in xrange(len(orgs)):
    plt.plot(timechange[i,:], label=orgs[i])
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## Generate figures

# %%
plt.figure(figsize=(8,50))
J = len(taxa_in_journal)
sums = Counter()
for j in xrange(J):
    key = taxa_in_journal.keys()[j]
    counts = []
    for t in tkeys:    # Use the same keys for all figures, so that taxon-groups are aligned.
        try:
            c = taxa_in_journal[key][t]
        except KeyError:
            c = 0
        counts.append(c)
        sums[t] += c

    ax = plt.subplot(J, 1, j+1)    # Subplots are arranged vertically.
    T = len(tkeys)

    ax.bar(arange(T), np.array(counts)+0.1, align='center', color='green', alpha=0.8, lw=2)
    
    # TODO: wrap tick label text?
    plt.xticks(arange(T))
    ax.set_xticklabels(tkeys, rotation=35, horizontalalignment='right')

    # TODO: clean this up....
    if key == 'the neuroscientist: a review journal bringing neurobiology, neurology and psychiatry':
        title = 'The Neuroscientist'
    elif key == 'cerebral cortex (new york, n.y.: 1991)':
        title = 'Cerebral Cortex'
    elif key == 'acs chemical neuroscience':
        title = 'ACS Chemical Neuroscience'
    else:
        title = key.title()
        
    plt.title('{0}, 2005-2010'.format(title))
plt.tight_layout()    # Fixes subplot spacing.
plt.show()

# %%
plt.figure( figsize=(10,7))
plt.bar(arange(len(sums)), [ sums[t] for t in tkeys ], align='center', color='green', alpha=0.8, lw=2)
plt.xticks(arange(len(sums)), tkeys, rotation=35, horizontalalignment='right')
plt.title('All Journals, 2005-2010')
plt.show()
